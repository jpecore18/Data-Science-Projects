# %% [markdown]
# # 1. Web Scraping Spotify and Genius Lyrics

# %% [markdown]
# # Problem Statement (**Goal**)

# %% [markdown]
# Spotify uses its popularity parameter in order to rank songs, albums, and artists. This "popularity" metric is based on how often users stream songs from Spotify. But how does this popularity metric by song-streaming compare with other metrics for popularity?
#
# What about popularity based on aspects of the music itself: like danceability, energy, and acousticness? What about popularity based on the content of an artist's lyrics--the verbal connotations and vibe of the poetry? And what about popularity based on Twitter users' reviews of the same music/artist? How do each of these factors influence our ability to predict the popularity of an artist or song?
#
# Finally, when using Regression modeling, Classification modeling, and Natural Language Processing Classification to predict the popularity of a musical artist, how can we use both these Spotify and non-Spotify popularity metrics to recommend which rising pop artists to fund, advertise, and support?

# %% [markdown]
# # Executive Summary (**Overview**)

# %% [markdown]
# Spotify Song Attributes
# 1. First (for Song Attributes), I scrape three different playlists off of Spotify full of "Pop Rising" songs and stars. I clean the data, removing NAN values and duplicates for the songs. Spotify has a built in popularity function based on number of streams, so I will compare those popularity of songs to those I will generate via regression model.
# 2. Second, I use a wide variety of Regression models to predict popularity of a song based on the song's metrics (like energy, danceability, acousticness, etc.) that spotify's audio analysis algorithm produces. Next, I use a wide variety of Classification models to predict whether a song is popular (metric above 70 popularity according to Spotify) or not (based on quality).
# 3. Finally, I interpret the differences between the stream-based popularity metric and this song-attribute-based popularity metric, generating reasons for incongruities.
#
# Genius Lyric Attributes
# 3. First (for Lyric Attributes), I use the shorter list of playlist songs (just ordered_playlist) from Spotify as a basis for which lyrics to scrape. I scrape the lyrics for each of these songs off of Genius' lyric library.
# 4. Second, I use sentiment analysis and NLP to perform EDA on the most common words/sentiments for each song.
# 5. Finally, I try to evaluate whether there is a correlation between most common words and song sentiment with its popularity.
#
# Lyric Clustering Processing (Stretch Goal)
# 6. First (for Lyrics), I use Word2Vec/Spacey to cluster the lyrics on certain words.
# 7. Finally, I try to evaluate whether there is a correlation between most common words and artist sentiment with their tweet popularity (positive tweets).

# %% [markdown]
# ### Stretch Goals

# %% [markdown]
# - Use Word2Vec/SpaCy to vectorize and cluster lyrics data for smaller dataset.
#
# - Build a Neural Network to predict popularity using information from Spotify.
#     Reached this goal!
#
# - Use Twitter to scrape tweets relating to artists.
#     - Not possible!
#     - Twitter edited their API, so no more scraping :(
#
# - Create a recommender system to recommend songs to people based on their desired mood
#     - Base recommender system off of BOTH lyrics and song attributes
#
# - Figure out other interesting information from the data! I collected SO MUCH interesting information, I want to know what further directions I can take this project towards that would benefit a record label or music/tech firm. Any suggestions would be highly appreciated.

# %% [markdown]
# ### Project Limitations/Assumptions

# %% [markdown]
# - Regression can be used to predict a song's popularity value to some degree of accuracy. If it cannot be predicted accurately enough, it means that Spotify popularity is not correlated with the actual qualities of the music.
# - Classification can be used to differentiate between unpopular (<70% popularity) and popular (>70% popularity).

# %% [markdown]
# # Standard Imports

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import time
import re

# bs4, nltk, and sklearn imports
from bs4 import BeautifulSoup   
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from sklearn import metrics
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

#pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# # Spotify Data Collection

# %%
# Referencing Spotipy API Tutorial by Medium Author Well Loot for following code
# https://medium.com/@RareLoot/extracting-spotify-data-on-your-favourite-artist-via-python-d58bc92a4330

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
import spotipy.util as util

# %%
client_id = "d7eee18620f34508b15f78ee4b9cfec4"
client_secret = "ea9cbeba0ebb43b2813c22564b03110c"

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %%
#testing artist scraping
name = "Nicki Minaj" #chosen artist
result = sp.search(name) #search query
result['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#   'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#   'id': '790FomKkXshlbRYZFtlgla',
#   'name': 'KAROL G',
#   'type': 'artist',
#   'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#   'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#   'id': '0hCNtLu0JehylgoiP8L4Gh',
#   'name': 'Nicki Minaj',
#   'type': 'artist',
#   'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}]

# %%
# sp.user_playlist_tracks("username", "playlist_id")
# following code developed with reference to Max Hilsdorf, medium author
# https://towardsdatascience.com/how-to-create-large-music-datasets-using-spotipy-40e7242cc6a6

# %%
sp.user_playlist_tracks("spotify", "37i9dQZF1DWUa8ZRTfalHk");

# %%
import pandas as pd

# %%
#https://towardsdatascience.com/how-to-create-large-music-datasets-using-spotipy-40e7242cc6a6
#Function based on function model from this, plus Spotify Database API tags
def analyze_playlist(creator, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist","album","track_name",  "track_id", "danceability","energy","key",
                              "loudness","mode", "speechiness","instrumentalness","liveness",
                              "valence","tempo", "duration_ms","time_signature", "acousticness"]
    
    # https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/
    
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Create empty dict
        playlist_features = {}
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        playlist_features["popularity"] = track["track"]["popularity"]
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_df_1 = analyze_playlist("Spotify", "37i9dQZF1DWUa8ZRTfalHk")
playlist_df_1.head()
# Out:
#            artist                                 album  \
# 0    Shawn Mendes                                Wonder
# 1  Julia Michaels                         Lie Like This
# 2          Halsey                                 Manic
# 3       Pop Smoke  Shoot For The Stars Aim For The Moon
# 4    Why Don't We                               Fallin'
#
#                 track_name                track_id  danceability  energy key  \
# 0                   Wonder  5KCbr5ndeby4y4ggthdiAb         0.333   0.637   1
# 1            Lie Like This  5yCXLEi384DHGRXYMXgjBR         0.735   0.694   1
# 2              I'm Not Mad  6SL8U8TtdwOtGhbmGzsMfX         0.780   0.684   0
# 3  What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y         0.709   0.548  10
# 4                  Fallin'  5GhJIMWAw0uMLgkdbt6uMz         0.606   0.900   0
#
#    loudness mode  speechiness  instrumentalness  liveness  valence    tempo  \
# 0    -4.904    0       0.0581          0.000018    0.1490    0.132  139.898
# 1    -5.721    1       0.0538          0.000002    0.0675    0.849  120.983
# 2    -5.758    1       0.0636          0.000000    0.1050    0.732  149.916
# 3    -8.493    1       0.3530          0.000002    0.1330    0.543   83.995
# 4    -4.504    1       0.1190          0.000000    0.0750    0.233  133.963
#
#   duration_ms time_signature  acousticness  popularity
# 0      172693              4        0.1310        84.0
# 1      218383              4        0.1360        69.0
# 2      173467              4        0.1700        71.0
# 3      160000              4        0.6500        89.0
# 4      216504              4        0.0101        75.0

# %%
playlist_df_2 = analyze_playlist("Linards Zahrins", "5HRNyPYz3WO0w7gBf0HK9O")
playlist_df_2.head()
# Out:
#            artist             album                    track_name  \
# 0          DaBaby  BLAME IT ON BABY  ROCKSTAR (feat. Roddy Ricch)
# 1        Doja Cat        Boss Bitch                    Boss Bitch
# 2  Linards Zarins        I Miss You                    I Miss You
# 3        Dua Lipa  Future Nostalgia                   Hallucinate
# 4          Zaryah            Invite                        Invite
#
#                  track_id  danceability  energy key  loudness mode  \
# 0  7ytR5pFWmSjzHJIeQkgog4         0.746   0.690  11    -7.956    1
# 1  78qd8dvwea0Gosb6Fe6j3k         0.707   0.955  10    -4.593    0
# 2  52g4ZRv99HEDcGNGWT9fG6         0.710   0.351   6   -10.476    1
# 3  1nYeVF5vIBxMxfPoL0SIWg         0.627   0.690  10    -5.396    0
# 4  75WEC68Cuu6bijnu2A6hPS         0.785   0.203   2   -18.369    0
#
#    speechiness instrumentalness  liveness  valence    tempo duration_ms  \
# 0       0.1640                0    0.1010   0.4970   89.977      181733
# 1       0.2220                0    0.2020   0.5750  125.989      134240
# 2       0.0284                0    0.1950   0.6610  104.935      197903
# 3       0.1390                0    0.0742   0.6270  122.053      208505
# 4       0.0749         0.000433    0.0908   0.0881  124.981      147840
#
#   time_signature  acousticness  popularity
# 0              4        0.2470        96.0
# 1              4        0.1270        84.0
# 2              4        0.0801         2.0
# 3              4        0.0330        82.0
# 4              4        0.0586        38.0

# %%
playlist_df_3 = analyze_playlist("Pop Rizing", "293s8bPv39QLRSXANkHfNa")
playlist_df_3.head()
# Out:
#           artist            album       track_name                track_id  \
# 0   Sharp Elijah           4 Life           4 Life  4ArOkJprDLRRZyy1mwnCR4
# 1  Kaitlyn Velez             FOMO             FOMO  3ANoQMolPtM6GHQ8zrGeVE
# 2          MASHI          Bridges          Bridges  4daRt4KvOAdwSCvwZH51rO
# 3          Ghita        Real Lies        Real Lies  0eOBx65BAaEi8IaKd24aJC
# 4   Sharp Elijah  Dance All Night  Dance All Night  5LwHCXAoq2po5My5qNRAeg
#
#    danceability  energy key  loudness mode  speechiness instrumentalness  \
# 0         0.684   0.579   4    -8.447    0       0.2050                0
# 1         0.761   0.475  11    -6.251    0       0.0463         1.33e-06
# 2         0.600   0.589   9    -6.039    0       0.0480                0
# 3         0.726   0.623   1    -5.517    0       0.0304         1.17e-05
# 4         0.751   0.725   0    -6.336    1       0.0384         0.000169
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0    0.2430    0.582  110.121      174545              4         0.229
# 1    0.0717    0.332  150.044      160000              4         0.265
# 2    0.0871    0.415  125.011      179680              4         0.430
# 3    0.1150    0.391  100.077      218702              4         0.112
# 4    0.1490    0.396  120.010      169042              4         0.161
#
#    popularity
# 0        23.0
# 1        48.0
# 2        12.0
# 3        42.0
# 4        20.0

# %%
playlist_df_4 = analyze_playlist("Chosen Pop", "5CmQB7YW2O3CQxnYktisbA") 
playlist_df_4.head()
# Out:
#       artist               album          track_name                track_id  \
# 0      Farii  How you wanna play  How you wanna play  5MjVX3LgkIK5ilhQ5ANLvV
# 1  Rico Vina           Moonlight           Moonlight  3RJ3yXvTdWq65Mv2CXoel5
# 2    d.ffect   I Love You Anyway   I Love You Anyway  4nx02xsiBNp7XRie0B2O4x
# 3     Rohail             Hideout             Hideout  3OJrudyx65i6n4wG4WZnvL
# 4   Le Twins             PANTERA             PANTERA  5OwWSGWFxUhBH0hLcPYfHM
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.746   0.601   7    -9.693    0       0.0827          0.000001
# 1         0.813   0.538   3   -10.256    0       0.1600          0.000000
# 2         0.555   0.705   8    -9.584    1       0.0322          0.446000
# 3         0.590   0.253   5   -13.245    1       0.0943          0.000003
# 4         0.740   0.756   0    -4.715    0       0.0770          0.000011
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0     0.261    0.412  115.020      221398              4        0.1170
# 1     0.149    0.775  112.054      190000              4        0.0313
# 2     0.111    0.252  150.069      178696              4        0.0106
# 3     0.109    0.160  102.095      199360              4        0.7550
# 4     0.125    0.654   96.954      176907              4        0.0448
#
#    popularity
# 0        36.0
# 1        38.0
# 2        21.0
# 3        25.0
# 4        38.0

# %%
playlist_df_5 = analyze_playlist("Chosen Rap", "6uXVAe8ty2JNTueizGD4tN") 
playlist_df_5.head()
# Out:
#           artist            album  \
# 0  Noah Versache          Be True
# 1   Rich The Kid         BOSS MAN
# 2        Roselli         Strapped
# 3        Mikeonl           Sicily
# 4         JAYDAY  Pineapple Fanta
#
#                                     track_name                track_id  \
# 0                                      Be True  3wnqp4AxntLVc30HyBMW6G
# 1  Racks On (feat. YoungBoy Never Broke Again)  03RLJVJKfqsuCZfnqlhJVh
# 2                                     Strapped  5B8YTG5V7IjmrsStzxXuu7
# 3                                       Sicily  1Q756SyFuCKPh3icN5jBx1
# 4                              Pineapple Fanta  58YUD9GCKkGkHKUzbr6DOq
#
#    danceability  energy key  loudness mode  speechiness instrumentalness  \
# 0         0.627   0.641   9    -7.184    1       0.0308                0
# 1         0.558   0.511   0    -6.404    1       0.2070                0
# 2         0.910   0.494  11    -9.078    0       0.2040          0.00731
# 3         0.918   0.439   1    -6.618    0       0.2130                0
# 4         0.797   0.591   4   -10.830    0       0.2000                0
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0     0.122    0.114  145.991      223556              4        0.1180
# 1     0.131    0.232  105.353      177867              5        0.1110
# 2     0.116    0.223  131.916      149091              4        0.0488
# 3     0.105    0.685  119.978      217365              4        0.5910
# 4     0.258    0.360   94.990      162672              4        0.0380
#
#    popularity
# 0        28.0
# 1         2.0
# 2        41.0
# 3        19.0
# 4        17.0

# %%
playlist_df_6 = analyze_playlist("Rising Rock", "1R6sNoFTMwJ6pFvjpzGEZH") 
playlist_df_6.head()
# Out:
#            artist            album       track_name                track_id  \
# 0  After the Calm  Home Sweet Home  Home Sweet Home  6DvEYe2c1d5pkkIDE2EIXk
# 1      Wildstreet       Born to Be       Born to Be  5TeZm9VbENB3JE1v3wSYk9
# 2         Glossii      Watching Me      Watching Me  1it6clwVMKCsJtUlgQSUxx
# 3  After the Calm         Greenway         Greenway  7Eu7LWwLrzNxWpQUNLHoXd
# 4   Amongst Liars  Burn the Vision  Burn the Vision  5g15dxdGa8KhXtpjanp86r
#
#    danceability  energy key  loudness mode  speechiness instrumentalness  \
# 0         0.547   0.940   9    -3.729    1       0.0552                0
# 1         0.542   0.965   6    -3.257    1       0.1180         0.000863
# 2         0.424   0.956   4    -5.277    0       0.0513                0
# 3         0.558   0.885  10    -5.680    1       0.0331           0.0068
# 4         0.552   0.893  11    -5.708    0       0.0390            0.185
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0    0.0806    0.722  130.035      175800              4      0.000061
# 1    0.2840    0.470  133.048      216067              4      0.002460
# 2    0.3470    0.808  162.035      192340              4      0.000122
# 3    0.1560    0.246  107.536      198837              4      0.000076
# 4    0.0815    0.308   93.997      248759              4      0.001200
#
#    popularity
# 0        31.0
# 1        35.0
# 2        30.0
# 3        14.0
# 4        36.0

# %%
playlist_df_7 = analyze_playlist("New Boots", "37i9dQZF1DX8S0uQvJ4gaa") 
playlist_df_7.head()
# Out:
#          artist                    album               track_name  \
# 0       Filmore             State I'm In         Nothing's Better
# 1  Canaan Smith          Colder Than You          Colder Than You
# 2  Maren Morris  Better Than We Found It  Better Than We Found It
# 3   Adam Doleac      Meet Me in the City      Meet Me in the City
# 4  Austin Burke            Speed of Life            Speed of Life
#
#                  track_id  danceability  energy key  loudness mode  \
# 0  1LtiNpTzzSX8qcvlPFLmeR         0.800   0.515   9    -5.431    1
# 1  2blxo5iZckUK1UraX8B1nq         0.378   0.810   3    -4.036    1
# 2  6IVLDX1miNBy1BOWebnMP2         0.379   0.569  10    -5.193    1
# 3  0swbLEe8Z5CKqvglG9zzmZ         0.501   0.738   7    -6.301    1
# 4  4bcefPrfEwg4UxqZFkMxzh         0.528   0.634   1    -6.574    0
#
#    speechiness instrumentalness  liveness  valence    tempo duration_ms  \
# 0       0.0351                0     0.355    0.949  110.018      193145
# 1       0.0468         6.52e-06     0.262    0.643  176.773      201619
# 2       0.0290         3.19e-06     0.166    0.230  170.219      197216
# 3       0.0803                0     0.204    0.520   87.166      176461
# 4       0.0273         0.000137     0.360    0.259   82.022      193339
#
#   time_signature  acousticness  popularity
# 0              4        0.0724        68.0
# 1              3        0.1170        57.0
# 2              3        0.1120        66.0
# 3              4        0.2460        54.0
# 4              4        0.0495        52.0

# %%
playlist_df_8 = analyze_playlist("Low-Key", "37i9dQZF1DX2yvmlOdMYzV")
playlist_df_8.head()
# Out:
#       artist                                  album  \
# 0  070 Shake  Guilty Conscience (Tame Impala Remix)
# 1    Simpson                Cherry Ice Cream Sundae
# 2    Alann8h                              Dumb Daze
# 3     Joesef                           I Wonder Why
# 4      OSHUN                                  Sango
#
#                               track_name                track_id  \
# 0  Guilty Conscience - Tame Impala Remix  4nNkCxutxk68CulzSBy0Tq
# 1                Cherry Ice Cream Sundae  2kp5QEtvCuWmDmc7prlDJq
# 2                      My Mind Is a Maze  2P4qoMmSqElFcI7GYaPLwf
# 3                           I Wonder Why  2HpDcssMlgQXfmAUYhePIP
# 4                                  Sango  4D7o2dM2OeEFXB1omK5aTF
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.416   0.878   1    -3.654    0       0.3220          0.004530
# 1         0.602   0.582   6    -7.981    1       0.0305          0.001260
# 2         0.850   0.223   1   -11.460    1       0.0705          0.000032
# 3         0.619   0.654   0    -8.541    0       0.0425          0.003320
# 4         0.588   0.263   1   -16.722    1       0.1940          0.000329
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0    0.2500    0.317  191.936      214987              4        0.0583
# 1    0.1070    0.670   89.976      192360              4        0.2260
# 2    0.0914    0.468   95.008      146678              4        0.6710
# 3    0.0604    0.726   80.000      228348              4        0.2090
# 4    0.1100    0.232   84.010      240482              4        0.7460
#
#    popularity
# 0        40.0
# 1         0.0
# 2        59.0
# 3        60.0
# 4        45.0

# %%
playlist_df_9 = analyze_playlist("Study Break", "37i9dQZF1DX1dvMSwf27JO")
playlist_df_9.head()
# Out:
#         artist          album     track_name                track_id  \
# 0        HANNI    Golden Eyes    Golden Eyes  2CVWGyKDFZRYzYkd9OxQRv
# 1        Rence      Baby Blue      Baby Blue  1eA6HGJ1qZXEL7NIFKYrXK
# 2    spill tab   Cotton Candy   Cotton Candy  7K1H5Peem34cxKy40kNFw5
# 3  Neeko Crowe  noway, trusay  noway, trusay  3Q3PynExfV1zosxXQ0wXgA
# 4  Taylor Hill       Like YOU       Like YOU  1LU9Dqce1Ri6q5b0ajkdIT
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.606   0.406   8    -9.689    1       0.0340          0.000030
# 1         0.518   0.411   7    -8.909    1       0.0335          0.000716
# 2         0.685   0.460   0    -7.809    1       0.2240          0.000013
# 3         0.895   0.434   0    -9.785    1       0.3660          0.000004
# 4         0.755   0.683   5    -2.317    1       0.0351          0.000000
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0    0.1620   0.1360   87.025      148252              4        0.6230
# 1    0.1120   0.0782  120.060      208000              4        0.8960
# 2    0.3570   0.5960   96.876       93871              3        0.6750
# 3    0.0925   0.6390  116.990      220000              4        0.6170
# 4    0.1050   0.6950  122.016      206576              4        0.0191
#
#    popularity
# 0        50.0
# 1        62.0
# 2        58.0
# 3        39.0
# 4        41.0

# %%
playlist_df_10 = analyze_playlist("Are & Be", "37i9dQZF1DX4SBhb3fqCJd")
playlist_df_10.head()
# Out:
#           artist                  album                  track_name  \
# 0       Ella Mai  Not Another Love Song       Not Another Love Song
# 1  Teyana Taylor           Wake Up Love                Wake Up Love
# 2         Giveon        Spotify Singles  LIKE I WANT YOU - Acoustic
# 3  Bryson Tiller  A N N I V E R S A R Y    Outta Time (feat. Drake)
# 4            SZA          Hit Different               Hit Different
#
#                  track_id  danceability  energy key  loudness mode  \
# 0  5XqDJFVCyRTm5J7cIfRmR1         0.499   0.612   4    -5.947    0
# 1  2KkNkv6ciB6bt2hvHtOrin         0.583   0.766  11    -4.743    0
# 2  0qXu4pFQSIwkfTUgkE6WzF         0.463   0.381  10    -7.660    0
# 3  0LGtMvQJ37SsEYbkP6TcVJ         0.714   0.582   5    -7.272    0
# 4  7Bar1kLTmsRmH6FCKKMEyU         0.679   0.516   0    -6.371    0
#
#    speechiness  instrumentalness  liveness  valence    tempo duration_ms  \
# 0       0.1270          0.000050    0.0993    0.218  157.218      217801
# 1       0.4050          0.000002    0.1590    0.203  131.374      215329
# 2       0.0309          0.001390    0.1090    0.256  117.762      185224
# 3       0.0808          0.000000    0.0774    0.338   92.819      198822
# 4       0.0452          0.000000    0.0965    0.716  120.074      202008
#
#   time_signature  acousticness  popularity
# 0              4        0.1710        67.0
# 1              3        0.5020        67.0
# 2              3        0.7980        69.0
# 3              4        0.0129        70.0
# 4              4        0.1990        81.0

# %%
playlist_df_large = analyze_playlist("Longest Playlist Ever", "5fMCrRnSy4TauAmM36zrIP")
playlist_df_large.head()
# Out:
#             artist                   album  \
# 0             Ween             The Mollusk
# 1        Daft Punk  Random Access Memories
# 2        Daft Punk  Random Access Memories
# 3        The Coral        Magic & Medicine
# 4  Various Artists              Cheap Date
#
#                                           track_name                track_id  \
# 0                                          Ocean Man  6M14BiCN00nOsba4JaYsHW
# 1             Fragments of Time (feat. Todd Edwards)  0IedgQjjJ8Ad4B3UDQ5Lyn
# 2  Get Lucky (feat. Pharrell Williams & Nile Rodg...  69kOkLUCkxIZYexIgSG8rq
# 3                                         Pass It On  5uB85PzlWrnNnxL2A1TcKD
# 4                                    Dreaming of You  40SE4lxCPNibwbdw1zzWV5
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.720   0.912   4    -6.130    1       0.0363          0.001220
# 1         0.807   0.510   0    -9.729    1       0.0433          0.115000
# 2         0.810   0.793   6    -9.404    0       0.0403          0.000002
# 3         0.395   0.727   7    -6.015    1       0.0375          0.000007
# 4         0.447   0.729   9    -6.108    0       0.0307          0.000370
#
#    liveness  valence    tempo duration_ms time_signature  acousticness  \
# 0    0.0982    0.973  122.782      126947              4        0.5510
# 1    0.1040    0.961  130.118      279773              4        0.0410
# 2    0.0720    0.863  116.049      369627              4        0.0378
# 3    0.0683    0.872  179.097      139133              4        0.2820
# 4    0.1090    0.971  199.098      141200              4        0.4310
#
#    popularity
# 0        65.0
# 1        58.0
# 2        72.0
# 3        52.0
# 4        33.0

# %%
new_song_df = pd.concat([playlist_df_1,playlist_df_2,playlist_df_3,playlist_df_4, playlist_df_5, playlist_df_6,playlist_df_7,playlist_df_8,playlist_df_9, playlist_df_10, playlist_df_large])
new_song_df.head()
# Out:
#            artist                                 album  \
# 0    Shawn Mendes                                Wonder
# 1  Julia Michaels                         Lie Like This
# 2          Halsey                                 Manic
# 3       Pop Smoke  Shoot For The Stars Aim For The Moon
# 4    Why Don't We                               Fallin'
#
#                 track_name                track_id  danceability  energy key  \
# 0                   Wonder  5KCbr5ndeby4y4ggthdiAb         0.333   0.637   1
# 1            Lie Like This  5yCXLEi384DHGRXYMXgjBR         0.735   0.694   1
# 2              I'm Not Mad  6SL8U8TtdwOtGhbmGzsMfX         0.780   0.684   0
# 3  What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y         0.709   0.548  10
# 4                  Fallin'  5GhJIMWAw0uMLgkdbt6uMz         0.606   0.900   0
#
#    loudness mode  speechiness instrumentalness  liveness  valence    tempo  \
# 0    -4.904    0       0.0581          1.8e-05    0.1490    0.132  139.898
# 1    -5.721    1       0.0538         1.72e-06    0.0675    0.849  120.983
# 2    -5.758    1       0.0636                0    0.1050    0.732  149.916
# 3    -8.493    1       0.3530         1.59e-06    0.1330    0.543   83.995
# 4    -4.504    1       0.1190                0    0.0750    0.233  133.963
#
#   duration_ms time_signature  acousticness  popularity
# 0      172693              4        0.1310        84.0
# 1      218383              4        0.1360        69.0
# 2      173467              4        0.1700        71.0
# 3      160000              4        0.6500        89.0
# 4      216504              4        0.0101        75.0

# %%
new_song_df.shape
# Out:
# (699, 18)

# %% [markdown]
# # Spotify Features Data Cleaning

# %%
desired_features = ['artist','track_name','popularity',"danceability","energy",
                              "loudness","mode", "speechiness","instrumentalness","liveness",
                              "valence","tempo", "duration_ms","time_signature","acousticness"]

# %%
ordered_songlist = new_song_df.sort_values('popularity', ascending = False)

# %%
ordered_songlist.shape
# Out:
# (699, 18)

# %%
ordered_songlist.reset_index(drop=True, inplace=True)

# %%
ordered_songlist.head()
# Out:
#           artist                                 album  \
# 0       24kGoldn                Mood (feat. Iann Dior)
# 1         DaBaby                      BLAME IT ON BABY
# 2  Justin Bieber                                  Holy
# 3  Ariana Grande                          Stuck with U
# 4      Pop Smoke  Shoot For The Stars Aim For The Moon
#
#                           track_name                track_id  danceability  \
# 0             Mood (feat. Iann Dior)  3tjFYV6RSFtuktYl3ZtYcq         0.700
# 1       ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4         0.746
# 2     Holy (feat. Chance The Rapper)  5u1n1kITHCxxp8twBcZxWy         0.673
# 3  Stuck with U (with Justin Bieber)  4HBZA5flZLE435QTztThqH         0.597
# 4            What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y         0.709
#
#    energy key  loudness mode  speechiness instrumentalness  liveness  valence  \
# 0   0.722   7    -3.558    0       0.0369                0    0.2720    0.756
# 1   0.690  11    -7.956    1       0.1640                0    0.1010    0.497
# 2   0.704   6    -8.056    1       0.3600                0    0.0898    0.372
# 3   0.450   8    -6.658    1       0.0418                0    0.3820    0.537
# 4   0.548  10    -8.493    1       0.3530         1.59e-06    0.1330    0.543
#
#      tempo duration_ms time_signature  acousticness  popularity
# 0   90.989      140526              4         0.221       100.0
# 1   89.977      181733              4         0.247        96.0
# 2   86.919      212093              4         0.196        93.0
# 3  178.765      228482              3         0.223        90.0
# 4   83.995      160000              4         0.650        89.0

# %%
ordered_songlist.shape
# Out:
# (699, 18)

# %%
ordered_songlist.drop_duplicates(inplace=True)

# %%
ordered_songlist.reset_index(inplace=True)

# %%
ordered_songlist.shape
# Out:
# (695, 19)

# %%
ordered_songlist.describe()
# Out:
#             index  danceability      energy    loudness  speechiness  \
# count  695.000000    695.000000  695.000000  695.000000   695.000000
# mean   350.569784      0.637235    0.615717   -7.391350     0.105578
# std    201.382807      0.143827    0.180804    2.772211     0.110802
# min      0.000000      0.240000    0.124000  -18.369000     0.023600
# 25%    177.500000      0.535000    0.484000   -9.077500     0.037250
# 50%    351.000000      0.645000    0.619000   -6.883000     0.056100
# 75%    524.500000      0.749500    0.749000   -5.317000     0.121500
# max    698.000000      0.981000    0.991000   -1.507000     0.777000
#
#          liveness     valence       tempo  acousticness  popularity
# count  695.000000  695.000000  695.000000    695.000000  695.000000
# mean     0.170024    0.478647  121.582358      0.239105   45.365468
# std      0.115636    0.213876   28.779929      0.252453   23.797027
# min      0.022800    0.050300   61.525000      0.000007    0.000000
# 25%      0.096450    0.324000   98.133500      0.026850   26.500000
# 50%      0.121000    0.471000  120.019000      0.150000   48.000000
# 75%      0.210500    0.640000  141.978000      0.405500   65.000000
# max      0.725000    0.973000  203.783000      0.977000  100.000000

# %%
ordered_songlist.isnull().sum()
# Out:
# index               0
# artist              0
# album               0
# track_name          0
# track_id            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# acousticness        0
# popularity          0
# dtype: int64

# %% [markdown]
# # Importing Gigantic Dataset to Improve Song Attribute Predictions

# %%
#Gigantic Songlist Data Source: https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db
large_df = pd.read_csv('spotify_features.csv')

# %%
large_df.reset_index(inplace=True)

# %%
large_df.head()
# Out:
#    index  genre        artist_name                        track_name  \
# 0      0  Movie     Henri Salvador       C'est beau de faire un Show
# 1      1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2      2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3      3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4      4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
large_df.shape
# Out:
# (232725, 19)

# %%
# # Dataset Pulled by Tgel0 on Github Using Approximately the following method (looked at and roughly transcribed for my purposes of understanding)

# # storing the track searching results
# artist = []
# track_name = []
# popularity = []
# track_id = []

# for i in range(0,10_000,50):
#     track_results = sp.search(q='year:2020', type='track', limit=50)
#     for i, t in enumerate(track_results['tracks']['items']): #i, t is used for enumerate instead of i, j because "t" stands for the track we are indexing by
#         artist.append(t['artists'][0]['name'])
#         track_name.append(t['name'])
#         track_id.append(t['id'])
#         popularity.append(t['popularity'])
        
# df_tracks = pd.DataFrame({'artist':artist,'track_name':track_name,'track_id':track_id,'popularity':popularity})
# print(df_tracks.shape)

# %%
# # we need to use batchsizes since there's a limit to how many tracks you can get audio features from in one query
# # empty list, batchsize and the counter for None results
# rows = []
# batchsize = 100
# None_counter = 0

# for i in range(0,len(df_tracks['track_id']),batchsize):
#     batch = df_tracks['track_id'][i:i+batchsize]
#     feature_results = sp.audio_features(batch)
#     for i, t in enumerate(feature_results):
#         if t == None:
#             None_counter = None_counter + 1
#         else:
#             rows.append(t)

# %%
# df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
# df_audio_features['track_id'] = df_audio_features['id']
# df_audio_features.head()

# %% [markdown]
# # Cleaning Gigantic Dataset

# %%
print("Shape of the dataset:", large_df.shape)
# Out:
# Shape of the dataset: (232725, 19)

# %%
large_df.drop_duplicates(subset=['track_name'], inplace=True)
print("Shape of the dataset:", large_df.shape)
large_df.head()
# Out:
# Shape of the dataset: (148615, 19)
#    index  genre        artist_name                        track_name  \
# 0      0  Movie     Henri Salvador       C'est beau de faire un Show
# 1      1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2      2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3      3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4      4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
large_df['mode'] = large_df['mode'].map({'Major':1, 'Minor':0});

# %%
large_df['artist'] = large_df['artist_name']
large_df.head()
# Out:
#    index  genre        artist_name                        track_name  \
# 0      0  Movie     Henri Salvador       C'est beau de faire un Show
# 1      1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2      2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3      3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4      4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness  mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828     1
# 1       137373   0.737             0.000  F#    0.1510    -5.559     0
# 2       170267   0.131             0.000   C    0.1030   -13.879     0
# 3       152427   0.326             0.000  C#    0.0985   -12.178     1
# 4        82625   0.225             0.123   F    0.2020   -21.150     1
#
#    speechiness    tempo time_signature  valence             artist
# 0       0.0525  166.969            4/4    0.814     Henri Salvador
# 1       0.0868  174.003            4/4    0.816  Martin & les fées
# 2       0.0362   99.488            5/4    0.368    Joseph Williams
# 3       0.0395  171.758            4/4    0.227     Henri Salvador
# 4       0.0456  140.576            4/4    0.390       Fabien Nataf

# %%
large_df.drop(columns=['artist_name'], inplace = True)

# %%
large_df.sort_values('popularity', ascending = False)[desired_features].head()
# Out:
#               artist                                track_name  popularity  \
# 9027   Ariana Grande                                   7 rings         100
# 86951    Post Malone                                      Wow.          99
# 9026   Ariana Grande  break up with your girlfriend, i'm bored          99
# 66643   Daddy Yankee                                 Con Calma          98
# 9028          Halsey                                Without Me          97
#
#        danceability  energy  loudness  mode  speechiness  instrumentalness  \
# 9027          0.725   0.321   -10.744     0       0.3230          0.000000
# 86951         0.833   0.539    -7.399     0       0.1780          0.000002
# 9026          0.726   0.554    -5.290     0       0.0917          0.000000
# 66643         0.737   0.860    -2.652     0       0.0593          0.000002
# 9028          0.752   0.488    -7.050     1       0.0705          0.000009
#
#        liveness  valence    tempo  duration_ms time_signature  acousticness
# 9027     0.0884    0.319   70.142       178640            4/4        0.5780
# 86951    0.1010    0.385   99.947       149520            4/4        0.1630
# 9026     0.1060    0.335  169.999       190440            4/4        0.0421
# 66643    0.0574    0.656   93.989       193227            4/4        0.1100
# 9028     0.0936    0.533  136.041       201661            4/4        0.2970

# %%
large_df.isnull().sum()
# Out:
# index               0
# genre               0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# artist              0
# dtype: int64

# %%
large_df.head(20)
# Out:
#     index  genre                                         track_name  \
# 0       0  Movie                        C'est beau de faire un Show
# 1       1  Movie                   Perdu d'avance (par Gad Elmaleh)
# 2       2  Movie                     Don't Let Me Be Lonely Tonight
# 3       3  Movie                     Dis-moi Monsieur Gordon Cooper
# 4       4  Movie                                          Ouverture
# 5       5  Movie                     Le petit souper aux chandelles
# 6       6  Movie  Premières recherches (par Paul Ventimila, Lori...
# 7       7  Movie                                      Let Me Let Go
# 8       8  Movie                                              Helka
# 9       9  Movie                          Les bisous des bisounours
# 10     10  Movie  Symphony No.4 In E Minor Op.98 : IV. Allegro E...
# 11     11  Movie  The Hanging (Maverick - Original Motion Pictur...
# 12     12  Movie                             J'ai demandé à la lune
# 13     13  Movie                                      Mangala Aarti
# 14     14  Movie                                       Keys of Love
# 15     15  Movie       Les aventures d'Arsène Lupin: 813 - Partie 6
# 16     16  Movie                                              Diane
# 17     17  Movie                                       Ultra Man 80
# 18     18  Movie                                            Veunise
# 19     19  Movie                               Ladies And Gentlemen
#
#                   track_id  popularity  acousticness  danceability  \
# 0   0BRjO6ga9RKCKjfDqeFgWV           0       0.61100         0.389
# 1   0BjC1NfoEOOusryehmNudP           1       0.24600         0.590
# 2   0CoSDzoNIKCRs124s9uTVy           3       0.95200         0.663
# 3   0Gc6TVm52BwZD07Ki6tIvf           0       0.70300         0.240
# 4   0IuslXpMROHdEPvSl1fTQK           4       0.95000         0.331
# 5   0Mf1jKa8eNAf1a4PwTbizj           0       0.74900         0.578
# 6   0NUiKYRd6jt1LKMYGkUdnZ           2       0.34400         0.703
# 7   0PbIF9YVD505GutwotpB5C          15       0.93900         0.416
# 8   0ST6uPfvaPpJLtQwhE6KfC           0       0.00104         0.734
# 9   0VSqZ3KStsjcfERGdcWpFO          10       0.31900         0.598
# 10  0XKgegoxLcIihK3Klpfo3N           0       0.92100         0.191
# 11  0hprxsuRM5vVCOfaM7l3gQ           2       0.03830         0.230
# 12  0jF6HUm18fg6QQCLHhfhC0           4       0.21500         0.680
# 13  0jIY0oRAp1T4mezDyEhOad           3       0.95800         0.758
# 14  0pXwl2CRP5awxHsF9eET3L           0       0.97000         0.400
# 15  0uWUjxM7oDPKpb3T2y3oZm           0       0.54800         0.588
# 16  0vS7Zid3q0dMyX8uMnlQ8s           0       0.70000         0.625
# 17  0x8xSaoSfQkOYUnG1nbga0           3       0.48800         0.744
# 18  113pHPsGwyeklEjLhnB3ZT           1       0.38100         0.451
# 19  12ZjoNweObu1k9rK4SOSdL           4       0.16100         0.522
#
#     duration_ms  energy  instrumentalness key  liveness  loudness  mode  \
# 0         99373  0.9100          0.000000  C#    0.3460    -1.828     1
# 1        137373  0.7370          0.000000  F#    0.1510    -5.559     0
# 2        170267  0.1310          0.000000   C    0.1030   -13.879     0
# 3        152427  0.3260          0.000000  C#    0.0985   -12.178     1
# 4         82625  0.2250          0.123000   F    0.2020   -21.150     1
# 5        160627  0.0948          0.000000  C#    0.1070   -14.970     1
# 6        212293  0.2700          0.000000  C#    0.1050   -12.675     1
# 7        240067  0.2690          0.000000  F#    0.1130    -8.949     1
# 8        226200  0.4810          0.000860   C    0.0765    -7.725     1
# 9        152694  0.7050          0.001250   G    0.3490    -7.790     1
# 10       566960  0.1450          0.529000   E    0.1410   -17.239     0
# 11       121333  0.1330          0.887000   C    0.0872   -19.051     1
# 12       213589  0.6000          0.072900  F#    0.1110    -7.702     0
# 13       308627  0.2640          0.000000  D#    0.0543   -11.966     1
# 14       159253  0.1740          0.933000   G    0.1300   -13.869     1
# 15      2447870  0.4050          0.000000  G#    0.7540   -15.550     1
# 16       523424  0.2370          0.000000   D    0.3190   -16.655     1
# 17       178107  0.9530          0.000000   E    0.4530    -4.986     1
# 18       194360  0.4910          0.000000   D    0.1520    -8.730     1
# 19       207240  0.7480          0.000007  C#    0.1110    -5.203     1
#
#     speechiness    tempo time_signature  valence                artist
# 0        0.0525  166.969            4/4   0.8140        Henri Salvador
# 1        0.0868  174.003            4/4   0.8160     Martin & les fées
# 2        0.0362   99.488            5/4   0.3680       Joseph Williams
# 3        0.0395  171.758            4/4   0.2270        Henri Salvador
# 4        0.0456  140.576            4/4   0.3900          Fabien Nataf
# 5        0.1430   87.479            4/4   0.3580        Henri Salvador
# 6        0.9530   82.873            4/4   0.5330     Martin & les fées
# 7        0.0286   96.827            4/4   0.2740           Laura Mayne
# 8        0.0460  125.080            4/4   0.7650                Chorus
# 9        0.0281  137.496            4/4   0.7180   Le Club des Juniors
# 10       0.0393   85.225            4/4   0.0849     Leopold Stokowski
# 11       0.0302   91.739            4/4   0.1180          Randy Newman
# 12       0.0258  110.026            4/4   0.4330  Idoles De La Musique
# 13       0.0496  110.068            3/4   0.7420                Chorus
# 14       0.0458  115.022            4/4   0.2700    Richard M. Sherman
# 15       0.9380   83.560            3/4   0.4800           Michel Roux
# 16       0.5610  108.508            3/4   0.2980    Jean Claude Corbel
# 17       0.0370  129.959            4/4   0.9260         Bernard Minet
# 18       0.0548   71.633            3/4   0.5160        Henri Salvador
# 19       0.0824  184.063            4/4   0.7330                Amalya

# %% [markdown]
# # Concatenating Small DF and Large DF into Giant Ordered DF

# %%
giant_ordered_df = pd.concat([ordered_songlist, large_df])

# %%
giant_ordered_df.head()
# Out:
#    index         artist                                 album  \
# 0      0       24kGoldn                Mood (feat. Iann Dior)
# 1      1         DaBaby                      BLAME IT ON BABY
# 2      2  Justin Bieber                                  Holy
# 3      3  Ariana Grande                          Stuck with U
# 4      4      Pop Smoke  Shoot For The Stars Aim For The Moon
#
#                           track_name                track_id  danceability  \
# 0             Mood (feat. Iann Dior)  3tjFYV6RSFtuktYl3ZtYcq         0.700
# 1       ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4         0.746
# 2     Holy (feat. Chance The Rapper)  5u1n1kITHCxxp8twBcZxWy         0.673
# 3  Stuck with U (with Justin Bieber)  4HBZA5flZLE435QTztThqH         0.597
# 4            What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y         0.709
#
#    energy key  loudness mode  speechiness instrumentalness  liveness  valence  \
# 0   0.722   7    -3.558    0       0.0369                0    0.2720    0.756
# 1   0.690  11    -7.956    1       0.1640                0    0.1010    0.497
# 2   0.704   6    -8.056    1       0.3600                0    0.0898    0.372
# 3   0.450   8    -6.658    1       0.0418                0    0.3820    0.537
# 4   0.548  10    -8.493    1       0.3530         1.59e-06    0.1330    0.543
#
#      tempo duration_ms time_signature  acousticness  popularity genre
# 0   90.989      140526              4         0.221       100.0   NaN
# 1   89.977      181733              4         0.247        96.0   NaN
# 2   86.919      212093              4         0.196        93.0   NaN
# 3  178.765      228482              3         0.223        90.0   NaN
# 4   83.995      160000              4         0.650        89.0   NaN

# %%
giant_ordered_df.drop(columns=['key','index','genre','track_id'], inplace = True)

# %%
giant_ordered_df.head()
# Out:
#           artist                                 album  \
# 0       24kGoldn                Mood (feat. Iann Dior)
# 1         DaBaby                      BLAME IT ON BABY
# 2  Justin Bieber                                  Holy
# 3  Ariana Grande                          Stuck with U
# 4      Pop Smoke  Shoot For The Stars Aim For The Moon
#
#                           track_name  danceability  energy  loudness mode  \
# 0             Mood (feat. Iann Dior)         0.700   0.722    -3.558    0
# 1       ROCKSTAR (feat. Roddy Ricch)         0.746   0.690    -7.956    1
# 2     Holy (feat. Chance The Rapper)         0.673   0.704    -8.056    1
# 3  Stuck with U (with Justin Bieber)         0.597   0.450    -6.658    1
# 4            What You Know Bout Love         0.709   0.548    -8.493    1
#
#    speechiness instrumentalness  liveness  valence    tempo duration_ms  \
# 0       0.0369                0    0.2720    0.756   90.989      140526
# 1       0.1640                0    0.1010    0.497   89.977      181733
# 2       0.3600                0    0.0898    0.372   86.919      212093
# 3       0.0418                0    0.3820    0.537  178.765      228482
# 4       0.3530         1.59e-06    0.1330    0.543   83.995      160000
#
#   time_signature  acousticness  popularity
# 0              4         0.221       100.0
# 1              4         0.247        96.0
# 2              4         0.196        93.0
# 3              3         0.223        90.0
# 4              4         0.650        89.0

# %% [markdown]
# ### All of the song data is in hand

# %% [markdown]
# # Genius Lyrics Data Collection

# %%
import lyricsgenius
genius = lyricsgenius.Genius("noljdbG6ASnbF8-q8YREqBhcY8nWCx4kTUxXqq2XJ23-4W5mNj_5SGeZfjy757Dt")

# %%
#ordered_songlist['track_name']

# %%
ordered_songlist.head()
# Out:
#    index         artist                                 album  \
# 0      0       24kGoldn                Mood (feat. Iann Dior)
# 1      1         DaBaby                      BLAME IT ON BABY
# 2      2  Justin Bieber                                  Holy
# 3      3  Ariana Grande                          Stuck with U
# 4      4      Pop Smoke  Shoot For The Stars Aim For The Moon
#
#                           track_name                track_id  danceability  \
# 0             Mood (feat. Iann Dior)  3tjFYV6RSFtuktYl3ZtYcq         0.700
# 1       ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4         0.746
# 2     Holy (feat. Chance The Rapper)  5u1n1kITHCxxp8twBcZxWy         0.673
# 3  Stuck with U (with Justin Bieber)  4HBZA5flZLE435QTztThqH         0.597
# 4            What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y         0.709
#
#    energy key  loudness mode  speechiness instrumentalness  liveness  valence  \
# 0   0.722   7    -3.558    0       0.0369                0    0.2720    0.756
# 1   0.690  11    -7.956    1       0.1640                0    0.1010    0.497
# 2   0.704   6    -8.056    1       0.3600                0    0.0898    0.372
# 3   0.450   8    -6.658    1       0.0418                0    0.3820    0.537
# 4   0.548  10    -8.493    1       0.3530         1.59e-06    0.1330    0.543
#
#      tempo duration_ms time_signature  acousticness  popularity
# 0   90.989      140526              4         0.221       100.0
# 1   89.977      181733              4         0.247        96.0
# 2   86.919      212093              4         0.196        93.0
# 3  178.765      228482              3         0.223        90.0
# 4   83.995      160000              4         0.650        89.0

# %%
# #test for a song
# genius.verbose = False
# genius.search_song(ordered_songlist.loc[36,'track_name'], ordered_songlist.loc[36,'artist'])

# %%
lyrics_list = []
genius.verbose = False # keeps us from having to see every song printed out as its lyrics are searched (saves time)

start_time = time.time()
for i in ordered_songlist.index:
    artist = ordered_songlist.loc[i,'artist']
#    print(artist)
    track_name = ordered_songlist.loc[i,'track_name']
#    print(track_name)
    try:
        song = genius.search_song(track_name, artist)
        lyrics = song.lyrics
    except:
        lyrics = ''
    lyrics_list.append(lyrics)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
ordered_songlist['lyrics'] = lyrics_list

# %%
ordered_songlist.head()

# %% [markdown]
# # Genius Lyrics - Lyric Cleaning

# %%
def cleaning_lyrics(single_song_lyrics): # Developed from 5.3 lesson with Patrick Wales Dinan
    # Function to convert a raw review to a string of words
    
    # 1. Remove HTML.
    lyrics_text = BeautifulSoup(single_song_lyrics, "lxml").get_text()
    
    # 2. Remove non-letters.
    letters_only = re.sub("[^a-zA-Z]", " ", lyrics_text)
    
    # 3. Convert to lower case, split into individual words.
    words = letters_only.lower().split()
    
    # 4. In Python, searching a set is much faster than searching
    # a list, so convert the stopwords to a set.
    stops = set(stopwords.words('english'))
    new_stops = ['intro','chorus','verse','bridge','outro',
                 'like', 'oh','yeah','ooh','cause',
                'know','wanna','let','say','one',
                'feel','ah','get','go','take','pre','got','la',
                'mind','think','made','back','ft']
    stops.update(new_stops)
    
    # 5. Remove stopwords.
    meaningful_words = [w for w in words if w not in stops]
    
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return(" ".join(meaningful_words))

# %%
# #testing the function
# cleaning_lyrics(ordered_songlist['lyrics'][36])

# %%
# We will now apply this lyric_cleaning process to every set of lyrics.
# Initialize an empty list to hold the clean lyrics.
clean_lyrics = []

# For every post in our training set...
for lyrics in ordered_songlist['lyrics']:
    
    # Convert lyrics to words, then append to clean_train_reviews.
    clean_lyrics.append(cleaning_lyrics(lyrics))

# %%
# Test confirmation of the lyric process
clean_lyrics[36]

# %%
ordered_songlist['lyrics'] = clean_lyrics

# %%
ordered_songlist.head()

# %% [markdown]
# # Exporting All DFs

# %%
giant_ordered_df.to_csv('giant_ordered_df.csv', index=False)

# %%
ordered_songlist.to_csv('ordered_songlist.csv',index=False)

# %%
large_df.to_csv('ordered_large_df.csv',index=False)

# %% [markdown]
# # Twitter Data Collection - Further Research for When Twitter Becomes Available to Scrape Again

# %%
# import tweepy

# %%
# auth = tweepy.OAuthHandler('3Yl9jmtyYvPUqlNfo2USaXsid', '1GiCFFplVNgaeHY7nNuDsp8JGe6ReupMBm7r60leP99027pyOR')
# auth.set_access_token('229257549-tvbno92WebencvssWdh7okWtqEAjbAHTw5zG2nx4', 'eU6GSzD2WdyDrNybRsXbQ559xTZBBfeNbpqEXlwtZSTN6')

# %%
# api = tweepy.API(auth)
# #test tweet pulling
# for tweet in tweepy.Cursor(api.search, q=artist).items(10):
#     print(tweet.text)

# %% [markdown]
# ### Go to Part 2. EDA for more!
